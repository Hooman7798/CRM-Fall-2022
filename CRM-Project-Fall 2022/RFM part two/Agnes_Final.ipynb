# %%
cd /content/drive/My Drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline   
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import OPTICS, cluster_optics_dbscan
from sklearn.cluster import AgglomerativeClustering 
import scipy.cluster.hierarchy as shc
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv( 'CRM-Project-Noorbehbahani-Dataset.csv' )

# %%
#fill missing values with zero
data = data.fillna(0)

# %%
#drop id to avoid it's effect on the results
data.drop('id', inplace=True, axis=1)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True,cmap='RdBu')
plt.title('Correlation Heatmap',fontsize=14)
plt.yticks(rotation =0)
plt.show()

# %%
# Delete High Correlated Attributes
data.drop('Emtiaze_review', inplace=True, axis=1)
data.drop('Miangin_Gheimat', inplace=True, axis=1)
data.drop('Miangin_Ketab', inplace=True, axis=1)
data.drop('Daghayeghe-Shenide shode', inplace=True, axis=1)

# %%
# copying data
df = data.copy()

# %%
#Standardization is a scaling technique wherein it makes the data scale-free by converting the statistical distribution of the data into the below format:
#mean - 0 (zero)
#standard deviation - 1

scaler = StandardScaler()
scaler.fit(df)
# transform
data_scaled = scaler.transform(df)
data_scaled[0]
# Out:
# array([ 0.05694432,  2.56031917,  2.28491752,  3.58354763, 10.44134984,
#         0.34085525, -0.43453904])

# %%
pca = PCA()
# fit PCA
pca.fit(data_scaled)
# PCA features
features = range(pca.n_components_)
# PCA transformed data
data_pca = pca.transform(data_scaled)

# %%
pca2 = PCA(n_components=2, svd_solver='full')
# fit PCA
pca2.fit(data_scaled)
# PCA transformed data
data_pca2 = pca2.transform(data_scaled)
print(data_pca2.shape)
# Out:
# (14084, 2)

# %%
xs = data_pca2[:,0]
ys = data_pca2[:,1]
plt.scatter(ys, xs)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %% [markdown]
# **Testing Number of clusters to find out best poosible K**

# %%
hc2= AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc2)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
#zs = train_X.iloc[:,2]
plt.scatter(ys, xs,c=labels)
#plt.scatter(ys, zs, c=labels)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
hc3= AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc3)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
#zs = train_X.iloc[:,2]
plt.scatter(ys, xs,c=labels)
#plt.scatter(ys, zs, c=labels)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
hc4= AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc4)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
#zs = train_X.iloc[:,2]
plt.scatter(ys, xs,c=labels)
#plt.scatter(ys, zs, c=labels)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
hc5= AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc5)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
#zs = train_X.iloc[:,2]
plt.scatter(ys, xs,c=labels)
#plt.scatter(ys, zs, c=labels)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
hc6= AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc6)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
#zs = train_X.iloc[:,2]
plt.scatter(ys, xs,c=labels)
#plt.scatter(ys, zs, c=labels)

plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
hc7= AgglomerativeClustering(n_clusters=7, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc7)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %% [markdown]
# **Using Silhouette score to determine best k**

# %%
k = [2, 3, 4, 5, 6 ,7]

silhouette_scores = []
silhouette_scores.append(
        silhouette_score(data_pca, hc2.fit_predict(data_pca)))
silhouette_scores.append(
        silhouette_score(data_pca, hc3.fit_predict(data_pca)))
silhouette_scores.append(
        silhouette_score(data_pca, hc4.fit_predict(data_pca)))
silhouette_scores.append(
        silhouette_score(data_pca, hc5.fit_predict(data_pca)))
silhouette_scores.append(
        silhouette_score(data_pca, hc6.fit_predict(data_pca)))
silhouette_scores.append(
        silhouette_score(data_pca, hc7.fit_predict(data_pca)))
 
# Plotting a bar graph to compare the results
c = 'red'
plt.bar(k , silhouette_scores , color = c)
plt.xlabel('Number of clusters', fontsize = 15)
plt.ylabel('S(i)', fontsize = 15)
plt.show()

# %% [markdown]
# **So We choose 2 as number of Clusters**

# %%
hc2= AgglomerativeClustering(n_clusters = 2, affinity='euclidean', linkage='ward')  
# Build pipeline
pipeline = make_pipeline(scaler, pca2, hc2)
# fit the model to the scaled dataset
model_fit = pipeline.fit(df)
# return a label for each data point based on their cluster
labels = model_fit.fit_predict(df)
df['Clusters'] = labels

# %%
# Scatter plot visuals with labels

xs = data_pca2[:,0]
ys = data_pca2[:,1]
plt.scatter(ys, xs,c=labels)
plt.grid(False)
plt.title('Scatter Plot of Customers data')
plt.xlabel('PCA-01')
plt.ylabel('PCA-02')

plt.show()

# %%
# Number of data points for each feature in each cluster
df.groupby('Clusters').count()
# Out:
#           Toole_Ketab  Majmoo_Gheimat  Review  Completion  \
# Clusters
# 0               11095           11095   11095       11095
# 1                2989            2989    2989        2989
#
#           Darkhaste-Poshtibani  Zamane_akharin_bazdid -Zamane_kharid  Target
# Clusters
# 0                        11095                                 11095   11095
# 1                         2989                                  2989    2989

# %%
cluster_heatmap_df = df.groupby(['Clusters'])[['Toole_Ketab','Majmoo_Gheimat','Review', 'Completion', 'Darkhaste-Poshtibani', 'Zamane_akharin_bazdid -Zamane_kharid', 'Target']].mean()
heatcmap = sns.diverging_palette(240, 20, as_cmap=True)

fig, ax = plt.subplots(1, 1, figsize=(6,6))

sns.heatmap(cluster_heatmap_df.T, 
    square=True,
    linewidth=3,
    vmax=80, 
    vmin=1,
    cmap=heatcmap,
    cbar=False, 
    annot=True,
    fmt='.4g',
    ax=ax,
);

ax.set_title('Cluster Summary');
plt.tight_layout()
